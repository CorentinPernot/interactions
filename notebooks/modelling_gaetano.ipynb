# %%
from src.game import Game

# %%
game_params = {"n_a": 500, "n_b": 50, "x": 0.05, "eta": 5, "grid_size": 25}
game = Game(**game_params)
game.play_game(t_max=200_001, save_every=10_000, plot=True)
# Out:
# ...
# 100%|██████████| 50/50 [00:00<00:00, 278.48it/s]
# Gif saved at : output/06_21_04_59/grid.gif
